# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
conn = sqlite3.connect('shopee.db')
query = 'SELECT * FROM items'

df = pd.read_sql_query(query, conn)

# %%
df.head()
# Out:
#             id    shop_id                                               name  \
# 0   8535475240  104741119  Áo Lót Nam Cotton W&W Áo Thun Trắng Cộc Tay Ch...
# 1  11608442526  104741119  Quần Đùi Ngủ Mặc Nhà Nam W&W Cạp Chun, Chất Li...
# 2   6190848264  104741119  Áo Thun Nam Polo W&W Dáng Regular Fit- Cổ Đức ...
# 3   8772409270  104741119  Combo Áo Lót Nam Ba Lỗ WW Màu Trắng Chất Liệu ...
# 4   2937465699  104741119  Áo Thun Tanktop Nam WW Siêu Mát, Thấm Hút Mồ H...
#
#    stock  sold  liked  comment  status   price  price_min  price_max  \
# 0    198   477     83       82  normal  105000     105000     152500
# 1    798   303    731       70  normal   54500      54500     163500
# 2     26    53    705       19  normal  212500     212500     212500
# 3     62   271    731       76  normal   95000      95000     285000
# 4     11   101    693       29  normal   87500      87500      87500
#
#    discount  rating_1  rating_2  rating_3  rating_4  rating_5
# 0        50         1         0         1         4        76
# 1        50         2         2         2         7        57
# 2        50         0         0         1         0        18
# 3         0         0         0         1         2        73
# 4        50         1         0         0         3        25

# %%
df[df['name'].str.contains('sơ mi')]
# Out:
#                id    shop_id  \
# 80    16086121635  111639450
# 94     3683529574  111639450
# 101   22042552184  111639450
# 107   12693524965  111639450
# 1519   9461767378   24710134
# ...           ...        ...
# 4398  14496322433   92937520
# 4399  14064158867   92937520
# 4401  12894777108   92937520
# 4405  11399358678   92937520
# 4408  10697665255   92937520
#
#                                                    name  stock  sold  liked  \
# 80                Áo sơ mi nhung tăm thêu PATTERN PA016    355  2552    852
# 94    Áo sơ mi họa tiết PATTERN Cuban shirt hoa lá đ...     47  4350   1166
# 101                     Bộ sơ mi đũi nhăn PATTERN PB007     18     2      4
# 107   Áo sơ mi nam cộc tay PATTERN Cuban shirt 5 màu...     87  2195   1118
# 1519  Áo sơ mi nam dài tay Café Sticky Free khử mùi ...    785  1649    360
# ...                                                 ...    ...   ...    ...
# 4398  OWEN - Áo sơ mi dài tay Regular Fit màu Xanh N...     20     0      1
# 4399  Áo sơ mi dài tay nam Owen Nano Regular Fit Xan...     11     1      1
# 4401  Áo sơ mi ngắn tay Nam Owen Bamboo Body Fit Xan...      6    10      4
# 4405  OWEN - Áo sơ mi dài tay Regular Fit Ghi Cafe T...     17     0      1
# 4408  Áo sơ mi Nam dài tay Owen Slim Fit Nền ghi mel...     15     3      4
#
#       comment  status   price  price_min  price_max  discount  rating_1  \
# 80        707  normal  199000     199000     199000        44         1
# 94        935  normal  169000     169000     169000        43         5
# 101         0  normal  269000     269000     269000        46         0
# 107       587  normal  169000     169000     169000        43         6
# 1519      521  normal  499000     499000     499000         0         1
# ...       ...     ...     ...        ...        ...       ...       ...
# 4398        0  normal  650000     650000     650000         0         0
# 4399        0  normal  312400     312400     312400        45         0
# 4401        3  normal  568000     568000     568000         0         0
# 4405        0  normal  690000     690000     690000         0         0
# 4408        0  normal  598000     598000     598000         0         0
#
#       rating_2  rating_3  rating_4  rating_5
# 80           3        16        49       638
# 94           7        11        52       860
# 101          0         0         0         0
# 107          4        10        52       515
# 1519         2         2        16       500
# ...        ...       ...       ...       ...
# 4398         0         0         0         0
# 4399         0         0         0         0
# 4401         0         0         0         3
# 4405         0         0         0         0
# 4408         0         0         0         0
#
# [511 rows x 17 columns]
